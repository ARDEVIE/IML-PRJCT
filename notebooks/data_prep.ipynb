# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.utils import load_data, clean_dataset, process_budget_revenue, feature_engineering_pipeline

data_path = '../data/original/TMDB_all_movies.csv' 
df = load_data(data_path)

print(f"Rows: {df.shape[0]}")

df = clean_dataset(df)

print(f"Rows after filtering: {df.shape[0]}")

df = process_budget_revenue(df)

df = feature_engineering_pipeline(df)

output_path = '../data/cleaned/TMDB_all_movies_cleaned.csv'

df.to_csv(output_path, index=False)

df.head(1)
# Out:
# Rows: 1135258
# Rows after filtering: 54092
#    id                title  vote_average  vote_count    status release_date  \
# 0   2                Ariel           7.1       356.0  Released   1988-10-21
# 1   3  Shadows in Paradise           7.3       426.0  Released   1986-10-17
# 2   5           Four Rooms           5.9      2753.0  Released   1995-12-09
#
#      revenue  runtime     budget original_language  ...  \
# 0        NaN     73.0        NaN                fi  ...
# 1        NaN     74.0        NaN                fi  ...
# 2  4257354.0     98.0  4000000.0                en  ...
#
#                              director_of_photography  \
# 0                                      Timo Salminen
# 1                                      Timo Salminen
# 2  Phil Parmet, Guillermo Navarro, Rodrigo García...
#
#                                              writers  \
# 0                                   [Aki Kaurismäki]
# 1                                   [Aki Kaurismäki]
# 2  [Alexandre Rockwell, Allison Anders, Quentin T...
#
#                                            producers      music_composer  \
# 0                                     Aki Kaurismäki                 NaN
# 1                                    Mika Kaurismäki                 NaN
# 2  Alexandre Rockwell, Quentin Tarantino, Lawrenc...  Combustible Edison
#
#   imdb_rating imdb_votes cast_size  \
# 0         7.4     9493.0        39
# 1         7.4     8339.0        33
# 2         6.7   115619.0        28
#
#                                             top_cast release_year  \
# 0        [Susanna Haavisto, Pentti Auer, Olli Varja]       1988.0
# 1  [Helmeri Pellonpää, Ulla Kuosmanen, Marina Mar...       1986.0
# 2  [Patricia Vonne, Kimberly Blair, Salma Hayek P...       1995.0
#
#   release_month
# 0          10.0
# 1          10.0
# 2          12.0
#
# [3 rows x 27 columns]
