# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.utils import load_data, clean_dataset, process_budget_revenue, feature_engineering_pipeline

data_path = '../data/original/TMDB_movie_dataset.csv' 
df = load_data(data_path)

df = process_budget_revenue(df)

print(f"Rows: {df.shape[0]}")

df = clean_dataset(df)

print(f"Rows after filtering: {df.shape[0]}")


df = feature_engineering_pipeline(df)

output_path = '../data/cleaned/TMDB_all_movies_cleaned.csv'

df.to_csv(output_path, index=False)

df.head(1)
# Out:
# Rows: 1135258
# Rows after filtering: 80648
#    id  title  vote_average  vote_count    status release_date  revenue  \
# 0   2  Ariel           7.1       356.0  Released   1988-10-21      NaN
#
#    runtime  budget original_language  ...  director_of_photography  \
# 0     73.0     NaN                fi  ...            Timo Salminen
#
#             writers       producers music_composer imdb_rating imdb_votes  \
# 0  [Aki Kaurismäki]  Aki Kaurismäki            NaN         7.4     9493.0
#
#   cast_size                                     top_cast release_year  \
# 0        39  [Susanna Haavisto, Pentti Auer, Olli Varja]       1988.0
#
#   release_month
# 0          10.0
#
# [1 rows x 27 columns]

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.utils import load_data, clean_dataset, process_budget_revenue, feature_engineering_pipeline

raw_data_path = '../data/original/TMDB_movie_dataset.csv' 
df = load_data(raw_data_path)

print(f"rows: {df.shape[0]}")

df = clean_dataset(df)

df = process_budget_revenue(df)

df = feature_engineering_pipeline(df)
 
print(f"rows after filtering: {df.shape[0]}")

output_path = '../data/cleaned/TMDB_movie_dataset_cleaned.csv'
df.to_csv(output_path, index=False)

df.head(3)
# Out:
# rows: 1331729
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22264\868341514.py in ?()
#      10 df = load_data(raw_data_path)
#      11
#      12 print(f"rows: {df.shape[0]}")
#      13
# ---> 14 df = clean_dataset(df)
#      15
#      16 df = process_budget_revenue(df)
#      17
#
# c:\Users\DMR\Documents\IML-PRJCT\IML-PRJCT\src\utils.py in ?(df)
#      15     'imdb_id', 'original_title', 'overview', 'tagline']
#      16     df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])
#      17
#      18     df = df.dropna(subset=['budget'])
# ---> 19     df = df[df['vote_count'] > 5000]
#      20
#      21     if 'status' in df.columns:
#      22         df = df[df['status'] == 'Released']
#
# c:\Users\DMR\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6673             ax = self._get_axis(agg_axis)
#    6674             indices = ax.get_indexer_for(subset)
#    6675             check = indices == -1
#    6676             if check.any():
# -> 6677                 raise KeyError(np.array(subset)[check].tolist())
#    6678             agg_obj = self.take(indices, axis=agg_axis)
#    6679
#    6680         if thresh is not lib.no_default:
#
# KeyError: ['imdb_rating']
