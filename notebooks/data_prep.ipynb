# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.utils import load_data, clean_dataset, process_budget_revenue, feature_engineering_pipeline

data_path = '../data/original/TMDB_all_movies.csv' 
df = load_data(data_path)

print(f"Rows: {df.shape[0]}")

df = clean_dataset(df)

print(f"Rows after filtering: {df.shape[0]}")

df = process_budget_revenue(df)

df = feature_engineering_pipeline(df)

output_path = '../data/cleaned/TMDB_all_movies_cleaned.csv'

df.to_csv(output_path, index=False)

df.head(3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 7
#       3 import os
#       5 sys.path.append(os.path.abspath(os.path.join('..')))
# ----> 7 from src.utils import load_data, clean_dataset, process_budget_revenue, feature_engineering_pipeline
#       9 data_path = '../data/original/TMDB_all_movies.csv'
#      10 df = load_data(data_path)
#
# ImportError: cannot import name 'feature_engineering_pipeline' from 'src.utils' (c:\Users\DMR\Documents\IML-PRJCT\IML-PRJCT\src\utils.py)
